# %% [markdown]
# # Introdução
# Neste notebook, são explorados os dados coletados na pesquisa anual do Datahackers de 2022 sobre o mercado de trabalho na área de Tecnologia da Informação no Brasil.
# Foram levantados insights cruciais sobre tendências, demandas e desafios enfrentados pelos profissionais de TI no Brasil. Além disso, a pesquisa contribui significativamente para o debate sobre diversidade no setor, incluindo questões de gênero, raça e outros aspectos relacionados à inclusão.
# Como objetivos, buscamos aprender e praticar técnicas de análise de dados utilizando Python e biblitoceas como Pandas, Matplotlib e Seaborn, além de extrair insights que nos ajudem a identificar padrões, tendências e correlações nos dados coletados.

# %% [markdown]
# ### Uso da biblitoteca Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd #importações
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_excel('/content/drive/MyDrive/Análise de Dados PrograMaria/planilha_modulo3.xlsx') #leitura dos dados

# %% [markdown]
# ### Análise do Excel

# %%
dados[dados['GENERO']=='Feminino']
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# ...

# %%
dados[dados['GENERO'].str.contains('não', na=False)]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 562          562  vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528        1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913        1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925        1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554        2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090        3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357        3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493        3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610        3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171        4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200        4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227        4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
# ...

# %%
dados[dados['IDADE']>30]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# ...          ...                               ...    ...         ...
# 4257        4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
# 4264        4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
dados[dados['IDADE']>30 & (dados['GENERO']=='Feminino')]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# ...          ...                               ...    ...         ...
# 4265        4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
dados.groupby('GENERO')['ID'].nunique() #soma de valores únicos
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique() #visualizar valores nulos
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados[dados['IDADE']>30]['NIVEL'].value_counts() #contar valores
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
dados[dados['IDADE']>30 & (dados['GENERO']=='Feminino')]['NIVEL'].value_counts() #contar valores com filtro de gênero
# Out:
# NIVEL
# Pleno     1050
# Júnior    1010
# Sênior     883
# Name: count, dtype: int64

# %%
pd.pivot_table(dados, values='ID', index='GENERO', columns='GESTOR?', aggfunc='count') #pivot table
# Out:
# GESTOR?                0.0  1.0
# GENERO
# Feminino               754  132
# Masculino             2212  578
# Prefiro não informar     9    2

# %% [markdown]
# ### Estatística Básica

# %%
import numpy as np

# %%
lista_idades = [23, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23]

# %%
np.sum(lista_idades) #soma das idades
# Out:
# 325

# %%
len(lista_idades) #quantidade de idades
# Out:
# 11

# %%
media = np.mean(lista_idades) #média das idades
print("Media aritmetica: ", media)
# Out:
# Media aritmetica:  29.545454545454547

# %%
lista_idades.sort() #ordenar idades
print(lista_idades)
# Out:
# [20, 22, 23, 23, 26, 30, 31, 32, 35, 40, 43]

# %%
mediana = np.median(lista_idades) #mediana das idades
print("Mediana: ", mediana)
# Out:
# Mediana:  30.0

# %% [markdown]
# ### Voltando ao Excel

# %%
dados['IDADE'].mean()
# Out:
# 31.169168453657374

# %%
dados['IDADE'].median()
# Out:
# 30.0

# %%
dados['IDADE'].mode() #idade que mais aparece
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
dados['IDADE'].std() #desvio padrão
# Out:
# 6.902802832143122

# %%
dados['IDADE'].min() #menor valor de idade
# Out:
# 18.0

# %%
dados['IDADE'].max() #maior valor de idade
# Out:
# 54.0

# %%
dados[dados['GENERO']=='Feminino']['IDADE'].mean() #média de idade dos funcionários do sexo feminino
# Out:
# 31.318051575931232

# %% [markdown]
# # Tratando valores faltantes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %% [markdown]
# #### Trabalhando coluna de gênero

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'] = dados['GENERO'].fillna('Prefiro não informar') #preencher valores nulos

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                  1055
# Masculino                 3194
# Prefiro não informar        12
# Prefiro não informar\t       9
# Name: ID, dtype: int64

# %% [markdown]
# #### Trabalhando coluna de idade

# %%
dados['IDADE'].isnull().value_counts() #valores faltantes (true)
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
media_17_21 = dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()

# %%
dados.loc[dados['IDADE'].isnull() & (dados['FAIXA IDADE']=='17-21'), 'IDADE'] = media_17_21 #localiza e substitui valores

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+    68
# Name: count, dtype: int64

# %%
dados[dados['FAIXA IDADE']=='55+']['IDADE'].mean()
# Out:
# nan

# %%
media_geral = dados['IDADE'].mean()
media_geral
# Out:
# 31.153517220250375

# %%
dados.loc[dados['IDADE'].isnull(), 'IDADE'] = media_geral

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# #### Tratando coluna salário

# %%
dados[dados['SALARIO'].isnull()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 12            12  zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34
# 28            28  ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24
# 34            34  zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24
# 39            39  zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34
# 63            63  zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29
# ...          ...                               ...    ...         ...
# 4242        4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29
# 4252        4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 12    Masculino         Branca  Não
# 28     Feminino          Parda  Não
# ...

# %%
dados[dados['SALARIO'].isnull()]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
dados['SALARIO'].median()
# Out:
# 7625.5

# %%
dados.loc[dados['SALARIO'].isnull(), 'SALARIO'] = dados['SALARIO'].median()

# %%
dados[dados['SALARIO'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, IDADE, FAIXA IDADE, GENERO, COR/RACA/ETNIA, PCD, EXPERIENCIA_PROFISSIONAL_PREJUDICADA, ASPECTOS_PREJUDICADOS, VIVE_NO_BRASIL, ESTADO ONDE MORA, UF ONDE MORA, REGIAO ONDE MORA, MUDOU DE ESTADO?, REGIAO DE ORIGEM, NIVEL DE ENSINO, ÁREA DE FORMAÇÃO, QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?, SETOR, NUMERO DE FUNCIONARIOS, GESTOR?, CARGO COMO GESTOR, CARGO ATUAL, NIVEL, FAIXA SALARIAL, QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?, QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?, SALARIO]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### Valores discrepantes (outliers)
#
# > Add blockquote

# %%
lista_idades = [23, 30, 32, 22, 26, 35, 400, 20, 43, 31, 23]

# %%
media = np.mean(lista_idades)
media
# Out:
# 62.27272727272727

# %%
desvio = np.std(lista_idades)
desvio
# Out:
# 106.99200557143674

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a1683dcf2e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a168672ff40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a1683dcd5a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a168672d660>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a168672f9d0>],
#  'means': []}

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a1683dedcf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a1683def3d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a1683decf70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a1683def070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a1683dee4a0>],
#  'means': []}

# %%
Q1 = dados['SALARIO' ].quantile(0.25)
Q1
# Out:
# 4751.5

# %%
Q3 = dados['SALARIO' ].quantile(0.75)
Q3
# Out:
# 11794.5

# %%
IQR = Q3 - Q1
IQR
# Out:
# 7043.0

# %%
limite_superior = Q3 + (1.5 * IQR)
limite_superior
# Out:
# 22359.0

# %%
limite_inferior = Q1 - (1.5 * IQR)
limite_inferior
# Out:
# -5813.0

# %%
dados['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %%
media_salario = dados['SALARIO'].mean()
media_salario
# Out:
# 10517.53348162023

# %%
desvio_salario = dados['SALARIO'].std()
desvio_salario
# Out:
# 18096.21098911858

# %%
limite_superior_salario = media_salario + (3 * desvio_salario)
limite_superior_salario
# Out:
# 64806.166448975964

# %% [markdown]
# ##### Após identificar os outliers, decidimos se os removeríamos ou substituiríamos. Neste caso, verificamos a faixa salarial e substituímos salários discrepantes pela média da faixa correspondente, garantindo coerência.

# %%
dados[dados['SALARIO']>limite_superior_salario]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %%
media_30_40 = dados[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']<limite_superior_salario)]['SALARIO'].mean()
media_30_40
# Out:
# 39002.194029850754

# %%
dados.loc[(dados['SALARIO']>limite_superior_salario) & (dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês'), 'SALARIO'] = media_30_40

# %%
dados[dados['SALARIO']>limite_superior_salario]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %% [markdown]
# ####  Intervalo de confiança e distribuição amostral

# %%
salarios = dados['SALARIO']
salarios
# Out:
# 0       11194.0
# 1        4695.0
# 2       14202.0
# 3       15463.0
# 4        7733.0
#          ...
# 4266     4329.0
# 4267     3758.0
# 4268    19607.0
# 4269      989.0
# 4270     3079.0
# Name: SALARIO, Length: 4271, dtype: float64

# %%
media_amostral = np.mean(salarios)
media_amostral
# Out:
# 10247.43200236234

# %%
desvio_amostral = np.std(salarios)
desvio_amostral
# Out:
# 14370.38041525522

# %%
nivel_confianca = 0.95
tamanho_amostra = len(salarios)
tamanho_amostra
# Out:
# 4271

# %%
from scipy import stats

# %%
erro_padrao = stats.sem(salarios)
erro_padrao
# Out:
# 219.91473399776862

# %%
intervalo_de_confianca = stats.t.interval(nivel_confianca, tamanho_amostra-1, loc=media_amostral, scale=erro_padrao)
intervalo_de_confianca
# Out:
# (9816.284832630186, 10678.579172094494)

# %% [markdown]
# #####  O intervalo de confiança de 95% entre 9816 e 10678 significa que estamos 95% confiantes de que a verdadeira média salarial da população está entre 9816 e 10678.

# %% [markdown]
# ###  Featuring Engineering

# %%
def preencher_nivel(gestor, nivel):
  if gestor == 1:
    return "Pessoa Gestora"
  else:
    return nivel

# %%
dados['NOVO NIVEL'] = dados.apply(lambda x: preencher_nivel(x['GESTOR?'], x['NIVEL']), axis=1)
dados['NOVO NIVEL']
# Out:
# 0               Júnior
# 1       Pessoa Gestora
# 2                Pleno
# 3               Sênior
# 4                Pleno
#              ...
# 4266             Pleno
# 4267             Pleno
# 4268    Pessoa Gestora
# 4269            Júnior
# 4270            Júnior
# Name: NOVO NIVEL, Length: 4271, dtype: object

# %%
dados = pd.get_dummies(dados, columns=['NIVEL'])
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
def determinar_geracao(idade):
  if 39< idade <=58:
    return 'Geração X'
  elif 29< idade <=39:
    return 'Millenial'
  elif 13< idade <=29:
    return 'Geração Z'
  else:
    return 'Outra Geração'

# %%
dados['GERACAO'] = dados['IDADE'].apply(determinar_geracao)
dados['GERACAO'].value_counts()
# Out:
# GERACAO
# Geração Z    1999
# Millenial    1761
# Geração X     511
# Name: count, dtype: int64

# %%
dados2 = pd.read_excel('/content/drive/MyDrive/Análise de Dados PrograMaria/Planilha_Aula_parte2.xlsx')

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
# ...

# %%
# prompt: Using dataframe dados2: merge

# Assuming you want to merge dados2 with another dataframe, for example, another dataframe called dados1.
# Replace 'dados1' and 'on_column' with the actual dataframe name and the column to merge on.
# This code will perform a left join by default (using the left dataframe, dados2)
merged_df = dados2.merge(dados1, on='ID', how='left')

#If you want inner join:
#merged_df = dados2.merge(dados1, on='ID', how='inner')

#If you want right join:
#merged_df = dados2.merge(dados1, on='ID', how='right')

#If you want outer join:
#merged_df = dados2.merge(dados1, on='ID', how='outer')

# Example of merging on multiple columns
# merged_df = dados2.merge(dados1, on=['ID', 'Another_Column'], how='left')

# %%
dados = dados.merge(dados2, on='ID', how='left')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
dados['EM BUSCA'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('em busca', case=False)
dados['EM BUSCA'].value_counts()
# Out:
# EM BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
dados['ABERTO_OPORTUNIDADES'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('aberto', case=False)
dados['ABERTO_OPORTUNIDADES'].value_counts()
# Out:
# ABERTO_OPORTUNIDADES
# False    2342
# True     1354
# Name: count, dtype: int64

# %% [markdown]
# # Correlação

# %%
correlacao_continua = dados['IDADE'].corr(dados['SALARIO'])
correlacao_continua
# Out:
# 0.17645997054558626

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente(coluna1, coluna2):
  tabela_cruzada = np.array(pd.crosstab(coluna1, coluna2))
  chi2 = chi2_contingency(tabela_cruzada)[0]
  soma = np.sum(tabela_cruzada)
  mini = min(tabela_cruzada.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
# Out:
# 0.04499106580480143

# %% [markdown]
# Aplicamos essa função para verificar a relação entre cor/raça/etnia e nível de ensino, obtendo um coeficiente de 0.044, indicando quase nenhuma relação. Este resultado sugere que, na nossa amostra, etnias diferentes têm níveis de ensino semelhantes.
